# %% [markdown]
# ## Project 3: Housing Price Regressions

# %% [markdown]
# ## Introduction

# %% [markdown]
# Project 3 is focused on regression models, utilizing a dataset that is used for a Kaggle competition for predicting house prices based on many characteristics, including some such as year built, roof material, type of foundation, and more.
#
# This dataset can be found <a href="https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/overview">here.</a>
#
# I will be doing 3 experiments in this project using three different regression models.

# %% [markdown]
# ## What is Regression?

# %% [markdown]
# Before I show my experiments, I'm going to explain what regression is.
#
# Regression, in essence, is analyzing relationships between variables and that can be used to predict continuous outcomes. It can be used to either analyze a single independent variable to a dependent variable, or multiple independent variables to a dependent variable.
#
#
# From there, different regression algorithms exist to try and explore these relationships and predict values. For example, a common regression (which will be used in experiment 1), is linear regression, which tries to establish a line of best fit to visualize the relationship between variables.
#
# These regression algorithms can be evaluated looking at a few different metrics.
#
# R squared / coefficient of determination is a common way of evaluating the effectiveness of a regression model and generally shows, between 0 and 1, how well the model did in calculating and predicting data.
#
# Mean Absolute Error is the sum of absolute value distance from points on a graph to the line of best fit. In essence, it's the absolute value mean of how "off" the points are, or the "error." The lower, the better.
#
# Mean Squared Error is similar, but instead of just summing the absolute value of the error, we are squaring it. Again, lower is better.
#
# Root Mean Squared Error again is similar, but we are taking the square root of Mean Squared Error, which will make it smaller. Lower is better.

# %% [markdown]
# ## Pre-Processing

# %% [markdown]
# Before jumping straight into an experiment, I'm just going to look at the data, see what needs adjusting to make sure my models can run without any major hitches.

# %%
import pandas as pd
import numpy as np
dataset = pd.read_csv("train.csv")
dataset
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
#check for nulls
null = dataset.isna().sum()[dataset.isna().sum() > 0]
null
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %% [markdown]
# Some of these features are null for almost every single row in this dataset, so I'll aim to drop those features and I will keep the rest. I'll drop features that have over 100 nulls, as there's only 1460 rows in the first place.

# %%
null_to_drop = dataset.isna().sum()[dataset.isna().sum() > 100]
dataset.drop(columns = null_to_drop.index, axis=1, inplace=True)

# %%
#check to make sure it worked
null = dataset.isna().sum()[dataset.isna().sum() > 0]
null
# Out:
# MasVnrType       8
# MasVnrArea       8
# BsmtQual        37
# BsmtCond        37
# BsmtExposure    38
# BsmtFinType1    37
# BsmtFinType2    38
# Electrical       1
# GarageType      81
# GarageYrBlt     81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# dtype: int64

# %% [markdown]
# From here, I'm just going to now drop the rows that have null values to clean up the data, and we will be losing some rows, but we should still have plenty to make our regression models.

# %%
dataset = dataset.dropna(axis=0)
null = dataset.isna().sum()[dataset.isna().sum() > 0]
null
# Out:
# Series([], dtype: int64)

# %% [markdown]
# Now, there are no nulls in the dataset.

# %% [markdown]
# Now, regression uses numbers, so I'm going to check the data types of each feature to make sure it will work properly with the regression models. I'll also see if I need to standardize any of the data before continuing.

# %%
dataset.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1338 entries, 0 to 1459
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1338 non-null   int64
#  1   MSSubClass     1338 non-null   int64
#  2   MSZoning       1338 non-null   object
#  3   LotArea        1338 non-null   int64
#  4   Street         1338 non-null   object
#  5   LotShape       1338 non-null   object
#  6   LandContour    1338 non-null   object
#  7   Utilities      1338 non-null   object
#  8   LotConfig      1338 non-null   object
#  9   LandSlope      1338 non-null   object
#  10  Neighborhood   1338 non-null   object
#  11  Condition1     1338 non-null   object
#  12  Condition2     1338 non-null   object
#  13  BldgType       1338 non-null   object
#  14  HouseStyle     1338 non-null   object
#  15  OverallQual    1338 non-null   int64
#  16  OverallCond    1338 non-null   int64
#  17  YearBuilt      1338 non-null   int64
#  18  YearRemodAdd   1338 non-null   int64
#  19  RoofStyle      1338 non-null   object
#  20  RoofMatl       1338 non-null   object
#  21  Exterior1st    1338 non-null   object
#  22  Exterior2nd    1338 non-null   object
#  23  MasVnrType     1338 non-null   object
#  24  MasVnrArea     1338 non-null   float64
#  25  ExterQual      1338 non-null   object
#  26  ExterCond      1338 non-null   object
#  27  Foundation     1338 non-null   object
#  28  BsmtQual       1338 non-null   object
#  29  BsmtCond       1338 non-null   object
#  30  BsmtExposure   1338 non-null   object
#  31  BsmtFinType1   1338 non-null   object
#  32  BsmtFinSF1     1338 non-null   int64
#  33  BsmtFinType2   1338 non-null   object
#  34  BsmtFinSF2     1338 non-null   int64
#  35  BsmtUnfSF      1338 non-null   int64
#  36  TotalBsmtSF    1338 non-null   int64
#  37  Heating        1338 non-null   object
#  38  HeatingQC      1338 non-null   object
#  39  CentralAir     1338 non-null   object
#  40  Electrical     1338 non-null   object
#  41  1stFlrSF       1338 non-null   int64
#  42  2ndFlrSF       1338 non-null   int64
#  43  LowQualFinSF   1338 non-null   int64
#  44  GrLivArea      1338 non-null   int64
#  45  BsmtFullBath   1338 non-null   int64
#  46  BsmtHalfBath   1338 non-null   int64
#  47  FullBath       1338 non-null   int64
#  48  HalfBath       1338 non-null   int64
#  49  BedroomAbvGr   1338 non-null   int64
#  50  KitchenAbvGr   1338 non-null   int64
#  51  KitchenQual    1338 non-null   object
#  52  TotRmsAbvGrd   1338 non-null   int64
#  53  Functional     1338 non-null   object
#  54  Fireplaces     1338 non-null   int64
#  55  GarageType     1338 non-null   object
#  56  GarageYrBlt    1338 non-null   float64
#  57  GarageFinish   1338 non-null   object
#  58  GarageCars     1338 non-null   int64
#  59  GarageArea     1338 non-null   int64
#  60  GarageQual     1338 non-null   object
#  61  GarageCond     1338 non-null   object
#  62  PavedDrive     1338 non-null   object
#  63  WoodDeckSF     1338 non-null   int64
#  64  OpenPorchSF    1338 non-null   int64
#  65  EnclosedPorch  1338 non-null   int64
#  66  3SsnPorch      1338 non-null   int64
#  67  ScreenPorch    1338 non-null   int64
#  68  PoolArea       1338 non-null   int64
#  69  MiscVal        1338 non-null   int64
#  70  MoSold         1338 non-null   int64
#  71  YrSold         1338 non-null   int64
#  72  SaleType       1338 non-null   object
#  73  SaleCondition  1338 non-null   object
#  74  SalePrice      1338 non-null   int64
# dtypes: float64(2), int64(35), object(38)
# memory usage: 794.4+ KB

# %% [markdown]
# I'm seeing there's 39 features that are objects, so let's check them out.

# %%
objectcols = dataset.select_dtypes(include='object')
objectcols.head(10)
# Out:
#   MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# 5       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 6       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 7       RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 8       RM   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 9       RL   Pave      Reg         Lvl    AllPub    Corner       Gtl
#
#   Neighborhood Condition1 Condition2  ... Electrical KitchenQual Functional  \
# 0      CollgCr       Norm       Norm  ...      SBrkr          Gd        Typ
# 1      Veenker      Feedr       Norm  ...      SBrkr          TA        Typ
# 2      CollgCr       Norm       Norm  ...      SBrkr          Gd        Typ
# 3      Crawfor       Norm       Norm  ...      SBrkr          Gd        Typ
# 4      NoRidge       Norm       Norm  ...      SBrkr          Gd        Typ
# 5      Mitchel       Norm       Norm  ...      SBrkr          TA        Typ
# 6      Somerst       Norm       Norm  ...      SBrkr          Gd        Typ
# 7       NWAmes       PosN       Norm  ...      SBrkr          TA        Typ
# 8      OldTown     Artery       Norm  ...      FuseF          TA       Min1
# 9      BrkSide     Artery     Artery  ...      SBrkr          TA        Typ
#
#   GarageType GarageFinish GarageQual GarageCond PavedDrive SaleType  \
# 0     Attchd          RFn         TA         TA          Y       WD
# 1     Attchd          RFn         TA         TA          Y       WD
# 2     Attchd          RFn         TA         TA          Y       WD
# 3     Detchd          Unf         TA         TA          Y       WD
# 4     Attchd          RFn         TA         TA          Y       WD
# 5     Attchd          Unf         TA         TA          Y       WD
# 6     Attchd          RFn         TA         TA          Y       WD
# 7     Attchd          RFn         TA         TA          Y       WD
# 8     Detchd          Unf         Fa         TA          Y       WD
# 9     Attchd          RFn         Gd         TA          Y       WD
#
#   SaleCondition
# 0        Normal
# 1        Normal
# 2        Normal
# 3       Abnorml
# 4        Normal
# 5        Normal
# 6        Normal
# 7        Normal
# 8       Abnorml
# 9        Normal
#
# [10 rows x 38 columns]

# %% [markdown]
# I would like to include as many features as I can into the experiments, so I'm going to change these categorical features into numerical ones by using Label Encoding, which essentially just assigns numerical values based on what the categorical data previously was. For example, if there was a column with 3 different possibilities of categories, the new numerical column will have either 0,1 or 2. Scikit learn has a module for this already.

# %%
from sklearn import preprocessing

objectcols = objectcols.apply(preprocessing.LabelEncoder().fit_transform)
objectcols.head(10)
# Out:
#    MSZoning  Street  LotShape  LandContour  Utilities  LotConfig  LandSlope  \
# 0         3       1         3            3          0          4          0
# 1         3       1         3            3          0          2          0
# 2         3       1         0            3          0          4          0
# 3         3       1         0            3          0          0          0
# 4         3       1         0            3          0          2          0
# 5         3       1         0            3          0          4          0
# 6         3       1         3            3          0          4          0
# 7         3       1         0            3          0          0          0
# 8         4       1         3            3          0          4          0
# 9         3       1         3            3          0          0          0
#
#    Neighborhood  Condition1  Condition2  ...  Electrical  KitchenQual  \
# 0             5           2           2  ...           4            2
# 1            24           1           2  ...           4            3
# 2             5           2           2  ...           4            2
# 3             6           2           2  ...           4            2
# 4            15           2           2  ...           4            2
# 5            11           2           2  ...           4            3
# 6            21           2           2  ...           4            2
# 7            14           4           2  ...           4            3
# 8            17           0           2  ...           1            3
# 9             3           0           0  ...           4            3
#
#    Functional  GarageType  GarageFinish  GarageQual  GarageCond  PavedDrive  \
# 0           6           1             1           4           4           2
# 1           6           1             1           4           4           2
# 2           6           1             1           4           4           2
# 3           6           5             2           4           4           2
# 4           6           1             1           4           4           2
# 5           6           1             2           4           4           2
# 6           6           1             1           4           4           2
# 7           6           1             1           4           4           2
# 8           2           5             2           1           4           2
# 9           6           1             1           2           4           2
#
#    SaleType  SaleCondition
# 0         8              4
# 1         8              4
# 2         8              4
# 3         8              0
# 4         8              4
# 5         8              4
# 6         8              4
# 7         8              4
# 8         8              0
# 9         8              4
#
# [10 rows x 38 columns]

# %% [markdown]
# Now, we can see the object data is now numerical.

# %%
objectcols.dtypes
# Out:
# MSZoning         int64
# Street           int64
# LotShape         int64
# LandContour      int64
# Utilities        int64
# LotConfig        int64
# LandSlope        int64
# Neighborhood     int64
# Condition1       int64
# Condition2       int64
# BldgType         int64
# HouseStyle       int64
# RoofStyle        int64
# RoofMatl         int64
# Exterior1st      int64
# Exterior2nd      int64
# MasVnrType       int64
# ExterQual        int64
# ExterCond        int64
# Foundation       int64
# BsmtQual         int64
# BsmtCond         int64
# BsmtExposure     int64
# BsmtFinType1     int64
# BsmtFinType2     int64
# Heating          int64
# HeatingQC        int64
# CentralAir       int64
# Electrical       int64
# KitchenQual      int64
# Functional       int64
# GarageType       int64
# GarageFinish     int64
# GarageQual       int64
# GarageCond       int64
# PavedDrive       int64
# SaleType         int64
# SaleCondition    int64
# dtype: object

# %% [markdown]
# So, let's add this to our main dataframe by removing the objects then concatenating these new numeric features. Lets verify the size/shape of the dataframe first so we can then compare at the end.

# %%
dataset.shape
# Out:
# (1338, 75)

# %% [markdown]
# So after merging, we should be expected 1338 rows and 75 columns still.

# %%
dataset_nums = dataset.select_dtypes(exclude=['object'])
dataset_objs = dataset.select_dtypes(include='object')

# %%
#now to concat back together using objectcols instead of dataset_objs
dataset_clean = pd.concat([dataset_nums, objectcols], axis=1)

# %%
dataset_clean.head(10)
# Out:
#    Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   1          60     8450            7            5       2003          2003
# 1   2          20     9600            6            8       1976          1976
# 2   3          60    11250            7            5       2001          2002
# 3   4          70     9550            7            5       1915          1970
# 4   5          60    14260            8            5       2000          2000
# 5   6          50    14115            5            5       1993          1995
# 6   7          20    10084            8            5       2004          2005
# 7   8          60    10382            7            6       1973          1973
# 8   9          50     6120            7            5       1931          1950
# 9  10         190     7420            5            6       1939          1950
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  Electrical  KitchenQual  \
# 0       196.0         706           0  ...           4            2
# 1         0.0         978           0  ...           4            3
# 2       162.0         486           0  ...           4            2
# 3         0.0         216           0  ...           4            2
# 4       350.0         655           0  ...           4            2
# 5         0.0         732           0  ...           4            3
# 6       186.0        1369           0  ...           4            2
# 7       240.0         859          32  ...           4            3
# 8         0.0           0           0  ...           1            3
# 9         0.0         851           0  ...           4            3
#
#    Functional  GarageType  GarageFinish  GarageQual  GarageCond  PavedDrive  \
# 0           6           1             1           4           4           2
# 1           6           1             1           4           4           2
# 2           6           1             1           4           4           2
# 3           6           5             2           4           4           2
# 4           6           1             1           4           4           2
# 5           6           1             2           4           4           2
# 6           6           1             1           4           4           2
# 7           6           1             1           4           4           2
# 8           2           5             2           1           4           2
# 9           6           1             1           2           4           2
#
#    SaleType  SaleCondition
# 0         8              4
# 1         8              4
# 2         8              4
# 3         8              0
# 4         8              4
# 5         8              4
# 6         8              4
# 7         8              4
# 8         8              0
# 9         8              4
#
# [10 rows x 75 columns]

# %%
dataset_clean.shape
# Out:
# (1338, 75)

# %% [markdown]
# The shape is what we started with, so no columns got messed up. Let's reconfirm our datatypes as well.

# %%
dataset_clean.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1338 entries, 0 to 1459
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1338 non-null   int64
#  1   MSSubClass     1338 non-null   int64
#  2   LotArea        1338 non-null   int64
#  3   OverallQual    1338 non-null   int64
#  4   OverallCond    1338 non-null   int64
#  5   YearBuilt      1338 non-null   int64
#  6   YearRemodAdd   1338 non-null   int64
#  7   MasVnrArea     1338 non-null   float64
#  8   BsmtFinSF1     1338 non-null   int64
#  9   BsmtFinSF2     1338 non-null   int64
#  10  BsmtUnfSF      1338 non-null   int64
#  11  TotalBsmtSF    1338 non-null   int64
#  12  1stFlrSF       1338 non-null   int64
#  13  2ndFlrSF       1338 non-null   int64
#  14  LowQualFinSF   1338 non-null   int64
#  15  GrLivArea      1338 non-null   int64
#  16  BsmtFullBath   1338 non-null   int64
#  17  BsmtHalfBath   1338 non-null   int64
#  18  FullBath       1338 non-null   int64
#  19  HalfBath       1338 non-null   int64
#  20  BedroomAbvGr   1338 non-null   int64
#  21  KitchenAbvGr   1338 non-null   int64
#  22  TotRmsAbvGrd   1338 non-null   int64
#  23  Fireplaces     1338 non-null   int64
#  24  GarageYrBlt    1338 non-null   float64
#  25  GarageCars     1338 non-null   int64
#  26  GarageArea     1338 non-null   int64
#  27  WoodDeckSF     1338 non-null   int64
#  28  OpenPorchSF    1338 non-null   int64
#  29  EnclosedPorch  1338 non-null   int64
#  30  3SsnPorch      1338 non-null   int64
#  31  ScreenPorch    1338 non-null   int64
#  32  PoolArea       1338 non-null   int64
#  33  MiscVal        1338 non-null   int64
#  34  MoSold         1338 non-null   int64
#  35  YrSold         1338 non-null   int64
#  36  SalePrice      1338 non-null   int64
#  37  MSZoning       1338 non-null   int64
#  38  Street         1338 non-null   int64
#  39  LotShape       1338 non-null   int64
#  40  LandContour    1338 non-null   int64
#  41  Utilities      1338 non-null   int64
#  42  LotConfig      1338 non-null   int64
#  43  LandSlope      1338 non-null   int64
#  44  Neighborhood   1338 non-null   int64
#  45  Condition1     1338 non-null   int64
#  46  Condition2     1338 non-null   int64
#  47  BldgType       1338 non-null   int64
#  48  HouseStyle     1338 non-null   int64
#  49  RoofStyle      1338 non-null   int64
#  50  RoofMatl       1338 non-null   int64
#  51  Exterior1st    1338 non-null   int64
#  52  Exterior2nd    1338 non-null   int64
#  53  MasVnrType     1338 non-null   int64
#  54  ExterQual      1338 non-null   int64
#  55  ExterCond      1338 non-null   int64
#  56  Foundation     1338 non-null   int64
#  57  BsmtQual       1338 non-null   int64
#  58  BsmtCond       1338 non-null   int64
#  59  BsmtExposure   1338 non-null   int64
#  60  BsmtFinType1   1338 non-null   int64
#  61  BsmtFinType2   1338 non-null   int64
#  62  Heating        1338 non-null   int64
#  63  HeatingQC      1338 non-null   int64
#  64  CentralAir     1338 non-null   int64
#  65  Electrical     1338 non-null   int64
#  66  KitchenQual    1338 non-null   int64
#  67  Functional     1338 non-null   int64
#  68  GarageType     1338 non-null   int64
#  69  GarageFinish   1338 non-null   int64
#  70  GarageQual     1338 non-null   int64
#  71  GarageCond     1338 non-null   int64
#  72  PavedDrive     1338 non-null   int64
#  73  SaleType       1338 non-null   int64
#  74  SaleCondition  1338 non-null   int64
# dtypes: float64(2), int64(73)
# memory usage: 794.4 KB

# %% [markdown]
# All numerical values, so we're almost good to go. I am going to drop the "Id" column because it has no correlation to price, it is simply for identification purposes and could throw off the models.

# %%
dataset_clean = dataset_clean.drop(columns = 'Id', axis=1)

# %%
dataset_clean.head(5)
# Out:
#    MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0          60     8450            7            5       2003          2003
# 1          20     9600            6            8       1976          1976
# 2          60    11250            7            5       2001          2002
# 3          70     9550            7            5       1915          1970
# 4          60    14260            8            5       2000          2000
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  Electrical  \
# 0       196.0         706           0        150  ...           4
# 1         0.0         978           0        284  ...           4
# 2       162.0         486           0        434  ...           4
# 3         0.0         216           0        540  ...           4
# 4       350.0         655           0        490  ...           4
#
#    KitchenQual  Functional  GarageType  GarageFinish  GarageQual  GarageCond  \
# 0            2           6           1             1           4           4
# 1            3           6           1             1           4           4
# 2            2           6           1             1           4           4
# 3            2           6           5             2           4           4
# 4            2           6           1             1           4           4
#
#    PavedDrive  SaleType  SaleCondition
# 0           2         8              4
# 1           2         8              4
# 2           2         8              4
# 3           2         8              0
# 4           2         8              4
#
# [5 rows x 74 columns]

# %%
dataset_clean.shape
# Out:
# (1338, 74)

# %% [markdown]
# Ok, that marks the end of general pre-processing, and now the experiments can begin.

# %% [markdown]
# ## Experiment 1

# %% [markdown]
# For experiment 1, I'm going to use all of the features in a basic linear regression from Scikit Learn. So this will exclude all columns that didn't have over 100 null values in them, with the categorical data being encoded so it can be included.
#
# This process will include what we're already familiar with - splitting the features from the target (which is SalePrice).

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X = dataset_clean.drop(columns = ['SalePrice'])
y = dataset_clean['SalePrice']

# %%
X
# Out:
#       MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0             60     8450            7            5       2003          2003
# 1             20     9600            6            8       1976          1976
# 2             60    11250            7            5       2001          2002
# 3             70     9550            7            5       1915          1970
# 4             60    14260            8            5       2000          2000
# ...          ...      ...          ...          ...        ...           ...
# 1455          60     7917            6            5       1999          2000
# 1456          20    13175            6            6       1978          1988
# 1457          70     9042            7            9       1941          2006
# 1458          20     9717            5            6       1950          1996
# 1459          20     9937            5            6       1965          1965
#
#       MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  Electrical  \
# 0          196.0         706           0        150  ...           4
# 1            0.0         978           0        284  ...           4
# 2          162.0         486           0        434  ...           4
# 3            0.0         216           0        540  ...           4
# 4          350.0         655           0        490  ...           4
# ...          ...         ...         ...        ...  ...         ...
# 1455         0.0           0           0        953  ...           4
# 1456       119.0         790         163        589  ...           4
# 1457         0.0         275           0        877  ...           4
# 1458         0.0          49        1029          0  ...           0
# 1459         0.0         830         290        136  ...           4
#
#       KitchenQual  Functional  GarageType  GarageFinish  GarageQual  \
# 0               2           6           1             1           4
# 1               3           6           1             1           4
# 2               2           6           1             1           4
# 3               2           6           5             2           4
# 4               2           6           1             1           4
# ...           ...         ...         ...           ...         ...
# 1455            3           6           1             1           4
# 1456            3           2           1             2           4
# 1457            2           6           1             1           4
# 1458            2           6           1             2           4
# 1459            3           6           1             0           4
#
#       GarageCond  PavedDrive  SaleType  SaleCondition
# 0              4           2         8              4
# 1              4           2         8              4
# 2              4           2         8              4
# 3              4           2         8              0
# 4              4           2         8              4
# ...          ...         ...       ...            ...
# 1455           4           2         8              4
# 1456           4           2         8              4
# 1457           4           2         8              4
# 1458           4           2         8              4
# 1459           4           2         8              4
#
# [1338 rows x 73 columns]

# %%
y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1338, dtype: int64

# %%
#using a 20% split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

lr = LinearRegression()

lr = lr.fit(X_train, y_train)

# %%
lr.score(X_test, y_test)
# Out:
# 0.8675134367688541

# %% [markdown]
# Just looking at the score alone, it's scoring 86%, which is a great score. I'm honestly surprised at how well that did. Let's look at a few more metrics for this model.

# %%
from sklearn import metrics

y_pred = lr.predict(X_test)

mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

# %%
print('Mean Absolute Error:', mae)
print('Mean Squared Error:', mse)
print('Root Mean Square Error:', rmse)
# Out:
# Mean Absolute Error: 19206.256223989156
# Mean Squared Error: 659648753.9253552
# Root Mean Square Error: 25683.628130101773

# %% [markdown]
# So to sum up our evaluations, our score or Coefficient of Determination was about 86%, with our error scores above. The only thing I'll comment on right now with these three numbers above is that the closer to 0, the better the score. I'll be comparing my other experiments to these metrics to compare how well the other experiments predicts sales prices.

# %% [markdown]
# ## Sources

# %% [markdown]
# <ul>
#     <li>https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/overview</li>
#     <li>https://pbpython.com/categorical-encoding.html</li>
#     <li>https://www.investopedia.com/terms/r/regression.asp</li>
#     <li>https://medium.com/acing-ai/how-to-evaluate-regression-models-d183b4f5853d</li>
# </ul>
